# %% [markdown]
# **import pandas & numpy library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **read the csv file **

# %%
df=pd.read_csv("/content/HumanBodyPerformance.csv")
df
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %% [markdown]
# **import matplotlib **

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(df['age'],df["height_cm"],c="red")
plt.title("scatter plot" , fontsize=15)
plt.xlabel("age")
plt.ylabel("height_cm")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['gender'],df["height_cm"],c="blue")
plt.title("scatter plot" , fontsize=15)
plt.xlabel("gender")
plt.ylabel("height_cm")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['age'],df["weight_kg"],c="y")
plt.title("scatter plot" , fontsize=15)

plt.xlabel("age")
plt.ylabel("weight_kg")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['gender'],df["weight_kg"],c="green")
plt.title("scatter plot" , fontsize=15)
plt.xlabel("gender")
plt.ylabel("weight_kg")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Histogram plot

# %%
plt.hist(df["age"],color="red",edgecolor="black", bins=15)
plt.title("histogram" , fontsize=15)
plt.xlabel("age")
plt.show()

# %%
plt.hist(df["gender"],color="b",edgecolor="black")
plt.title("histogram" , fontsize=15)
plt.xlabel("gender")
plt.show()

# %%
plt.hist(df["height_cm"],color="y",edgecolor="black")
plt.title("histogram" , fontsize=15)
plt.xlabel("height_cm")
plt.show()

# %% [markdown]
# # Bar plot

# %%
plt.bar(df["gender"],df["height_cm"],color="g",width=0.1,align="center")
plt.title("bar plot" , fontsize=15)
plt.xlabel("gender")
plt.ylabel("height_cm")
plt.show()

# %%
plt.bar(df["age"],df["height_cm"],color="b",width=0.5,align="center")
plt.title("bar plot" , fontsize=15)
plt.xlabel("age")
plt.ylabel("height_cm")
plt.show()

# %%
plt.bar(df["age"],df["weight_kg"],color="y",width=0.5,align="center")
plt.title("bar plot" , fontsize=15)
plt.xlabel("age")
plt.ylabel("weight_kg")
plt.show()

# %%
plt.bar(df["gender"],df["weight_kg"],color="g",width=0.5,align="center")
plt.title("bar plot" , fontsize=15)
plt.xlabel("gender")
plt.ylabel("weight_kg")
plt.show()
